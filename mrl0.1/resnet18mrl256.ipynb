# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torchvision.models import resnet18
from torch.utils.data import DataLoader
import numpy as np

# %%
class Matryoshka_CE_Loss(nn.Module):
    def __init__(self, relative_importance=None, **kwargs):
        super(Matryoshka_CE_Loss, self).__init__()
        self.criterion = nn.CrossEntropyLoss(**kwargs)
        self.relative_importance = relative_importance

    def forward(self, output, target):
        losses = torch.stack([self.criterion(output_i, target) for output_i in output])
        rel_importance = torch.ones_like(losses) if self.relative_importance is None else torch.as_tensor(self.relative_importance, device=losses.device).clone().detach()        
        weighted_losses = rel_importance * losses
        return weighted_losses.sum()

class MRL_Linear_Layer(nn.Module):
    def __init__(self, nesting_list, num_classes=100, efficient=False, **kwargs):
        super(MRL_Linear_Layer, self).__init__()
        self.nesting_list = nesting_list
        self.num_classes = num_classes
        self.efficient = efficient
        if self.efficient:
            self.nesting_classifier_0 = nn.Linear(nesting_list[-1], self.num_classes, **kwargs)
        else:
            for i, num_feat in enumerate(self.nesting_list):
                setattr(self, f"nesting_classifier_{i}", nn.Linear(num_feat, self.num_classes, **kwargs))

    def forward(self, x):
        nesting_logits = ()
        for i, num_feat in enumerate(self.nesting_list):
            if self.efficient:
                if self.nesting_classifier_0.bias is None:
                    nesting_logits += (torch.matmul(x[:, :num_feat], (self.nesting_classifier_0.weight[:, :num_feat]).t()), )
                else:
                    nesting_logits += (torch.matmul(x[:, :num_feat], (self.nesting_classifier_0.weight[:, :num_feat]).t()) + self.nesting_classifier_0.bias, )
            else:
                nesting_logits += (getattr(self, f"nesting_classifier_{i}")(x[:, :num_feat]),)
        return nesting_logits

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda:0

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5071, 0.4867, 0.4408), (0.2675, 0.2565, 0.2761)),
])

train_set = torchvision.datasets.CIFAR100(root='./data', train=True, download=True, transform=transform_train)
test_set = torchvision.datasets.CIFAR100(root='./data', train=False, download=True, transform=transform_test)

train_loader = DataLoader(train_set, batch_size=128, shuffle=True, num_workers=1)
test_loader = DataLoader(test_set, batch_size=100, shuffle=False, num_workers=1)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# тут меняется размер фиксированного слоя
nesting_list = [256]
relative_importance = [1.0]
relative_importance_tensor = torch.tensor(relative_importance, device=device)
model = resnet18(weights=None)
model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
model.fc = MRL_Linear_Layer(nesting_list, num_classes=100, efficient=False)
model = model.to(device)

# %%
def train(epoch):
    model.train()
    train_loss = 0
    correct = {n: 0 for n in nesting_list}
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        for i, n in enumerate(nesting_list):
            _, predicted = outputs[i].max(1)
            correct[n] += predicted.eq(targets).sum().item()
        total += targets.size(0)

    avg_acc = 100. * sum(correct.values()) / (total * len(nesting_list))
    print(f"| {'Train':^6} {epoch:^3} | Loss: {train_loss/((batch_idx+1) * len(nesting_list)):^7.3f} | Acc: {avg_acc:^6.3f}% |")

# %%
def test(epoch):
    model.eval()
    test_loss = 0
    correct_top1 = {n: 0 for n in nesting_list}
    correct_top5 = {n: 0 for n in nesting_list}
    total = 0
    
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(test_loader):
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            test_loss += loss.item()
            
            for i, n in enumerate(nesting_list):
                _, predicted = outputs[i].max(1)
                correct_top1[n] += predicted.eq(targets).sum().item()
                
                _, top5_pred = outputs[i].topk(5, 1, True, True)
                correct_top5[n] += top5_pred.eq(targets.view(-1, 1)).sum().item()
            
            total += targets.size(0)

    avg_top1 = sum(100. * correct_top1[n] / total for n in nesting_list) / len(nesting_list)
    avg_top5 = sum(100. * correct_top5[n] / total for n in nesting_list) / len(nesting_list)
    
    print("\n┌──────────┬────────────┬────────────┐")
    print(f"│ {'Size':^8} │ {'Top-1 Acc':^10} │ {'Top-5 Acc':^10} │")
    print("├──────────┼────────────┼────────────┤")
    
    for n in nesting_list:
        top1 = 100. * correct_top1[n] / total
        top5 = 100. * correct_top5[n] / total
        print(f"│ {n:^8} │ {top1:>9.2f}% │ {top5:>9.2f}% │")
    
    print("├──────────┼────────────┼────────────┤")
    print(f"│ {'Average':^8} │ {avg_top1:>9.2f}% │ {avg_top5:>9.2f}% │")
    print("└──────────┴────────────┴────────────┘")
    
    return avg_top1

# %%
criterion = Matryoshka_CE_Loss(relative_importance=relative_importance_tensor)
optimizer = optim.SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=200)

# %%
import time
from datetime import timedelta

total_start_time = time.time()
epoch_times = []

best_acc = 0
for epoch in range(200):
    epoch_start = time.time()
    train(epoch)
    acc = test(epoch)
    scheduler.step()
    
    epoch_time = time.time() - epoch_start
    epoch_times.append(epoch_time)

    if acc > best_acc:
        best_acc = acc
        torch.save(model.state_dict(), 'best_model_mrl_256.pth')
    print(f'Epoch time: {timedelta(seconds=int(epoch_time))}')
    print('-' * 80)

total_time = time.time() - total_start_time
print(f'Total training time: {timedelta(seconds=int(total_time))}')
print(f'Average epoch time: {timedelta(seconds=int(sum(epoch_times)/len(epoch_times)))}')    

print(f'Best Test Accuracy: {best_acc:.2f}%')

import matplotlib.pyplot as plt
def imshow(img):
    img = img * torch.tensor([0.2675, 0.2565, 0.2761]).view(3, 1, 1) + \
          torch.tensor([0.5071, 0.4867, 0.4408]).view(3, 1, 1)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

dataiter = iter(test_loader)
images, labels = next(dataiter)
imshow(torchvision.utils.make_grid(images[:4]))
print('GroundTruth:\t', '\t'.join(f'{labels[j]}' for j in range(4)))

print("Size\t\t" + "\t".join(f"Image {j+1}" for j in range(4)))
outputs = model(images[:4].to(device))
for i, n in enumerate(nesting_list):
    _, predicted = torch.max(outputs[i], 1)
    print(f"{n}\t\t" + "\t".join(f"{predicted[j].item()}" for j in range(4)))
# Out:
# | Train   0  | Loss:  3.770  | Acc: 11.842% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     19.23% │     47.75% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     19.23% │     47.75% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train   1  | Loss:  3.098  | Acc: 22.698% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     26.30% │     57.23% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     26.30% │     57.23% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train   2  | Loss:  2.703  | Acc: 30.314% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     33.79% │     66.28% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     33.79% │     66.28% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train   3  | Loss:  2.459  | Acc: 35.490% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     36.74% │     68.83% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     36.74% │     68.83% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train   4  | Loss:  2.273  | Acc: 39.342% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     39.68% │     72.02% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     39.68% │     72.02% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train   5  | Loss:  2.140  | Acc: 42.238% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     41.91% │     74.79% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     41.91% │     74.79% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train   6  | Loss:  2.042  | Acc: 44.404% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     38.69% │     71.39% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     38.69% │     71.39% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train   7  | Loss:  1.961  | Acc: 46.648% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     45.01% │     76.23% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     45.01% │     76.23% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train   8  | Loss:  1.892  | Acc: 48.094% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     45.39% │     76.51% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     45.39% │     76.51% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train   9  | Loss:  1.832  | Acc: 49.686% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     42.24% │     74.03% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     42.24% │     74.03% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  10  | Loss:  1.774  | Acc: 50.722% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     44.48% │     75.19% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     44.48% │     75.19% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  11  | Loss:  1.748  | Acc: 51.606% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     47.93% │     78.84% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     47.93% │     78.84% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  12  | Loss:  1.700  | Acc: 52.726% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     46.86% │     77.10% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     46.86% │     77.10% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  13  | Loss:  1.659  | Acc: 53.534% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     45.87% │     75.83% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     45.87% │     75.83% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  14  | Loss:  1.634  | Acc: 54.298% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     47.72% │     77.87% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     47.72% │     77.87% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  15  | Loss:  1.618  | Acc: 54.542% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     48.46% │     79.71% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     48.46% │     79.71% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  16  | Loss:  1.587  | Acc: 55.276% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     49.88% │     79.30% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     49.88% │     79.30% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  17  | Loss:  1.560  | Acc: 55.966% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     49.96% │     79.17% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     49.96% │     79.17% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  18  | Loss:  1.543  | Acc: 56.514% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     51.93% │     81.67% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     51.93% │     81.67% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  19  | Loss:  1.524  | Acc: 56.944% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     51.36% │     81.12% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     51.36% │     81.12% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  20  | Loss:  1.510  | Acc: 57.264% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     50.89% │     81.37% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     50.89% │     81.37% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  21  | Loss:  1.489  | Acc: 57.886% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     48.32% │     78.87% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     48.32% │     78.87% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  22  | Loss:  1.479  | Acc: 57.928% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     50.54% │     79.95% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     50.54% │     79.95% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  23  | Loss:  1.478  | Acc: 58.108% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     49.35% │     77.79% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     49.35% │     77.79% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  24  | Loss:  1.457  | Acc: 58.716% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     49.03% │     79.02% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     49.03% │     79.02% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  25  | Loss:  1.438  | Acc: 58.876% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.98% │     81.86% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.98% │     81.86% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  26  | Loss:  1.429  | Acc: 59.274% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.20% │     82.22% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.20% │     82.22% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  27  | Loss:  1.429  | Acc: 59.288% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.34% │     81.32% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.34% │     81.32% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  28  | Loss:  1.409  | Acc: 60.040% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     50.95% │     80.28% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     50.95% │     80.28% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  29  | Loss:  1.404  | Acc: 59.952% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.52% │     83.44% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.52% │     83.44% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  30  | Loss:  1.393  | Acc: 60.258% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     51.93% │     81.25% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     51.93% │     81.25% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  31  | Loss:  1.388  | Acc: 60.466% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     50.68% │     79.83% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     50.68% │     79.83% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  32  | Loss:  1.372  | Acc: 60.730% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.56% │     82.04% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.56% │     82.04% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  33  | Loss:  1.370  | Acc: 60.632% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     52.89% │     81.33% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     52.89% │     81.33% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  34  | Loss:  1.353  | Acc: 61.230% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     54.31% │     82.74% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     54.31% │     82.74% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  35  | Loss:  1.344  | Acc: 61.640% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     55.05% │     83.30% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     55.05% │     83.30% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  36  | Loss:  1.331  | Acc: 61.768% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     51.77% │     81.70% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     51.77% │     81.70% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  37  | Loss:  1.338  | Acc: 61.742% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     52.96% │     83.06% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     52.96% │     83.06% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  38  | Loss:  1.322  | Acc: 62.224% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     49.39% │     78.97% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     49.39% │     78.97% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  39  | Loss:  1.322  | Acc: 61.994% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     55.81% │     83.56% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     55.81% │     83.56% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  40  | Loss:  1.310  | Acc: 62.786% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     55.33% │     83.43% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     55.33% │     83.43% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  41  | Loss:  1.305  | Acc: 62.860% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     52.61% │     81.10% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     52.61% │     81.10% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  42  | Loss:  1.303  | Acc: 62.418% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     50.27% │     80.68% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     50.27% │     80.68% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  43  | Loss:  1.298  | Acc: 62.774% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.86% │     82.57% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.86% │     82.57% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  44  | Loss:  1.287  | Acc: 63.046% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     55.05% │     82.86% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     55.05% │     82.86% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  45  | Loss:  1.276  | Acc: 63.242% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     54.85% │     82.46% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     54.85% │     82.46% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  46  | Loss:  1.270  | Acc: 63.470% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     55.45% │     84.01% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     55.45% │     84.01% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  47  | Loss:  1.263  | Acc: 63.494% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     52.85% │     82.02% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     52.85% │     82.02% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  48  | Loss:  1.256  | Acc: 63.700% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.64% │     83.53% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.64% │     83.53% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  49  | Loss:  1.257  | Acc: 63.608% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     52.70% │     81.47% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     52.70% │     81.47% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  50  | Loss:  1.236  | Acc: 64.224% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.34% │     84.37% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.34% │     84.37% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  51  | Loss:  1.235  | Acc: 64.322% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     57.28% │     84.92% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     57.28% │     84.92% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  52  | Loss:  1.225  | Acc: 64.750% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     54.02% │     81.70% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     54.02% │     81.70% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  53  | Loss:  1.228  | Acc: 64.416% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     51.76% │     80.07% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     51.76% │     80.07% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  54  | Loss:  1.203  | Acc: 65.102% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     55.58% │     83.48% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     55.58% │     83.48% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  55  | Loss:  1.211  | Acc: 64.732% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     55.78% │     83.21% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     55.78% │     83.21% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  56  | Loss:  1.202  | Acc: 65.208% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     52.18% │     80.18% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     52.18% │     80.18% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  57  | Loss:  1.194  | Acc: 65.358% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.37% │     83.94% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.37% │     83.94% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  58  | Loss:  1.194  | Acc: 65.052% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     57.48% │     84.29% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     57.48% │     84.29% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  59  | Loss:  1.184  | Acc: 65.710% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.28% │     84.62% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.28% │     84.62% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  60  | Loss:  1.182  | Acc: 65.506% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     55.62% │     84.01% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     55.62% │     84.01% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  61  | Loss:  1.170  | Acc: 66.000% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.00% │     81.66% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.00% │     81.66% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  62  | Loss:  1.156  | Acc: 66.318% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.23% │     81.74% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.23% │     81.74% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  63  | Loss:  1.147  | Acc: 66.498% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     53.38% │     80.55% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     53.38% │     80.55% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  64  | Loss:  1.150  | Acc: 66.218% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.33% │     83.84% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.33% │     83.84% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  65  | Loss:  1.131  | Acc: 66.818% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     57.64% │     84.82% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     57.64% │     84.82% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  66  | Loss:  1.143  | Acc: 66.776% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.49% │     83.77% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.49% │     83.77% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  67  | Loss:  1.122  | Acc: 67.202% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.20% │     85.13% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.20% │     85.13% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  68  | Loss:  1.123  | Acc: 67.272% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     54.59% │     82.67% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     54.59% │     82.67% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  69  | Loss:  1.107  | Acc: 67.562% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.50% │     83.71% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.50% │     83.71% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  70  | Loss:  1.095  | Acc: 67.806% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     57.09% │     84.20% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     57.09% │     84.20% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  71  | Loss:  1.095  | Acc: 67.834% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     57.80% │     84.17% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     57.80% │     84.17% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  72  | Loss:  1.090  | Acc: 68.000% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.32% │     85.38% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.32% │     85.38% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  73  | Loss:  1.073  | Acc: 68.580% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     54.80% │     83.21% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     54.80% │     83.21% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  74  | Loss:  1.074  | Acc: 68.226% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.77% │     84.23% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.77% │     84.23% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  75  | Loss:  1.067  | Acc: 68.546% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     57.90% │     84.45% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     57.90% │     84.45% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  76  | Loss:  1.050  | Acc: 68.768% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.88% │     84.56% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.88% │     84.56% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  77  | Loss:  1.054  | Acc: 68.794% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.26% │     84.99% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.26% │     84.99% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  78  | Loss:  1.042  | Acc: 69.292% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     57.87% │     84.81% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     57.87% │     84.81% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  79  | Loss:  1.024  | Acc: 69.668% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     57.94% │     84.56% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     57.94% │     84.56% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  80  | Loss:  1.009  | Acc: 70.144% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.30% │     85.94% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.30% │     85.94% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  81  | Loss:  1.015  | Acc: 69.972% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.77% │     85.35% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.77% │     85.35% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  82  | Loss:  0.994  | Acc: 70.628% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.38% │     84.67% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.38% │     84.67% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  83  | Loss:  0.999  | Acc: 70.430% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.68% │     85.24% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.68% │     85.24% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  84  | Loss:  0.992  | Acc: 70.514% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.03% │     85.57% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.03% │     85.57% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  85  | Loss:  0.982  | Acc: 70.700% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     56.72% │     84.29% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     56.72% │     84.29% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  86  | Loss:  0.962  | Acc: 71.298% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     60.21% │     85.79% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     60.21% │     85.79% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  87  | Loss:  0.953  | Acc: 71.582% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.66% │     85.45% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.66% │     85.45% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  88  | Loss:  0.949  | Acc: 71.652% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.44% │     84.99% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.44% │     84.99% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  89  | Loss:  0.944  | Acc: 71.596% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.76% │     85.17% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.76% │     85.17% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  90  | Loss:  0.928  | Acc: 72.400% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.23% │     84.58% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.23% │     84.58% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  91  | Loss:  0.912  | Acc: 72.622% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.14% │     84.96% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.14% │     84.96% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  92  | Loss:  0.909  | Acc: 72.954% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.56% │     85.41% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.56% │     85.41% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  93  | Loss:  0.904  | Acc: 72.864% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.49% │     86.11% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.49% │     86.11% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  94  | Loss:  0.885  | Acc: 73.496% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.86% │     85.20% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.86% │     85.20% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  95  | Loss:  0.877  | Acc: 73.546% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     60.38% │     86.78% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     60.38% │     86.78% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  96  | Loss:  0.866  | Acc: 73.930% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     60.23% │     85.93% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     60.23% │     85.93% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  97  | Loss:  0.851  | Acc: 74.306% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.07% │     85.10% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.07% │     85.10% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  98  | Loss:  0.866  | Acc: 73.794% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.96% │     85.86% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.96% │     85.86% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  99  | Loss:  0.831  | Acc: 74.850% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     58.86% │     84.47% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     58.86% │     84.47% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  100 | Loss:  0.823  | Acc: 75.250% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     61.38% │     85.96% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     61.38% │     85.96% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  101 | Loss:  0.821  | Acc: 75.068% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.70% │     85.10% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.70% │     85.10% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  102 | Loss:  0.808  | Acc: 75.368% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     60.35% │     86.20% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     60.35% │     86.20% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  103 | Loss:  0.800  | Acc: 75.688% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.59% │     86.17% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.59% │     86.17% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  104 | Loss:  0.784  | Acc: 76.122% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     61.62% │     87.37% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     61.62% │     87.37% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  105 | Loss:  0.770  | Acc: 76.460% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     60.76% │     86.69% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     60.76% │     86.69% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  106 | Loss:  0.766  | Acc: 76.598% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     60.04% │     86.46% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     60.04% │     86.46% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  107 | Loss:  0.745  | Acc: 77.330% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     60.67% │     86.08% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     60.67% │     86.08% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  108 | Loss:  0.737  | Acc: 77.388% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     59.18% │     85.51% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     59.18% │     85.51% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  109 | Loss:  0.739  | Acc: 77.380% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     61.12% │     86.59% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     61.12% │     86.59% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  110 | Loss:  0.713  | Acc: 77.872% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     61.28% │     86.85% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     61.28% │     86.85% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  111 | Loss:  0.700  | Acc: 78.466% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     60.38% │     86.16% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     60.38% │     86.16% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  112 | Loss:  0.690  | Acc: 78.620% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     62.74% │     87.05% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     62.74% │     87.05% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  113 | Loss:  0.677  | Acc: 78.992% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     62.06% │     86.20% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     62.06% │     86.20% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# ...
# │   256    │     69.05% │     89.12% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     69.05% │     89.12% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  163 | Loss:  0.062  | Acc: 98.394% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     68.65% │     89.10% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     68.65% │     89.10% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  164 | Loss:  0.050  | Acc: 98.774% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     69.40% │     89.56% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     69.40% │     89.56% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  165 | Loss:  0.048  | Acc: 98.840% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     69.64% │     89.48% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     69.64% │     89.48% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  166 | Loss:  0.045  | Acc: 98.896% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     69.62% │     89.40% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     69.62% │     89.40% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  167 | Loss:  0.039  | Acc: 99.140% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     69.85% │     89.22% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     69.85% │     89.22% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  168 | Loss:  0.034  | Acc: 99.290% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     70.07% │     89.86% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     70.07% │     89.86% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  169 | Loss:  0.029  | Acc: 99.444% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     70.19% │     89.91% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     70.19% │     89.91% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  170 | Loss:  0.026  | Acc: 99.508% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     70.91% │     89.95% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     70.91% │     89.95% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  171 | Loss:  0.023  | Acc: 99.546% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     70.62% │     89.78% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     70.62% │     89.78% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  172 | Loss:  0.022  | Acc: 99.602% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     70.93% │     89.94% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     70.93% │     89.94% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  173 | Loss:  0.020  | Acc: 99.664% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.29% │     90.16% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.29% │     90.16% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  174 | Loss:  0.018  | Acc: 99.734% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.38% │     90.19% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.38% │     90.19% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  175 | Loss:  0.017  | Acc: 99.732% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.60% │     90.33% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.60% │     90.33% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  176 | Loss:  0.015  | Acc: 99.798% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.46% │     90.20% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.46% │     90.20% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  177 | Loss:  0.015  | Acc: 99.782% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.87% │     90.25% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.87% │     90.25% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  178 | Loss:  0.014  | Acc: 99.806% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.70% │     90.31% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.70% │     90.31% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  179 | Loss:  0.013  | Acc: 99.858% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.08% │     90.26% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.08% │     90.26% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  180 | Loss:  0.012  | Acc: 99.832% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.95% │     90.30% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.95% │     90.30% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  181 | Loss:  0.012  | Acc: 99.874% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.83% │     90.33% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.83% │     90.33% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  182 | Loss:  0.012  | Acc: 99.854% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.05% │     90.43% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.05% │     90.43% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  183 | Loss:  0.011  | Acc: 99.866% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.94% │     90.40% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.94% │     90.40% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  184 | Loss:  0.011  | Acc: 99.874% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.01% │     90.36% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.01% │     90.36% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  185 | Loss:  0.010  | Acc: 99.886% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.92% │     90.47% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.92% │     90.47% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  186 | Loss:  0.010  | Acc: 99.886% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.12% │     90.55% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.12% │     90.55% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  187 | Loss:  0.010  | Acc: 99.880% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.19% │     90.48% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.19% │     90.48% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  188 | Loss:  0.010  | Acc: 99.912% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.38% │     90.42% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.38% │     90.42% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  189 | Loss:  0.010  | Acc: 99.906% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.22% │     90.55% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.22% │     90.55% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  190 | Loss:  0.009  | Acc: 99.916% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.22% │     90.43% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.22% │     90.43% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  191 | Loss:  0.009  | Acc: 99.924% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.33% │     90.44% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.33% │     90.44% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  192 | Loss:  0.009  | Acc: 99.906% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.17% │     90.50% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.17% │     90.50% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  193 | Loss:  0.009  | Acc: 99.906% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.28% │     90.35% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.28% │     90.35% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  194 | Loss:  0.009  | Acc: 99.936% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.16% │     90.50% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.16% │     90.50% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  195 | Loss:  0.009  | Acc: 99.924% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.36% │     90.47% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.36% │     90.47% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  196 | Loss:  0.009  | Acc: 99.902% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     71.95% │     90.29% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     71.95% │     90.29% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  197 | Loss:  0.009  | Acc: 99.922% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.27% │     90.45% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.27% │     90.45% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:19
# --------------------------------------------------------------------------------
# | Train  198 | Loss:  0.009  | Acc: 99.942% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.32% │     90.39% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.32% │     90.39% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# | Train  199 | Loss:  0.009  | Acc: 99.916% |
#
# ┌──────────┬────────────┬────────────┐
# │   Size   │ Top-1 Acc  │ Top-5 Acc  │
# ├──────────┼────────────┼────────────┤
# │   256    │     72.15% │     90.48% │
# ├──────────┼────────────┼────────────┤
# │ Average  │     72.15% │     90.48% │
# └──────────┴────────────┴────────────┘
# Epoch time: 0:00:18
# --------------------------------------------------------------------------------
# Total training time: 1:03:14
# Average epoch time: 0:00:18
# Best Test Accuracy: 72.38%
# GroundTruth:	 49	33	72	51
# Size		Image 1	Image 2	Image 3	Image 4
# 256		68	33	55	51
